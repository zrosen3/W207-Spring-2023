# %% [markdown]
# <a href="https://colab.research.google.com/github/zrosen3/W207-Spring-2023/blob/main/10_CNN_Rosen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 10

# %% [markdown]
# ### <span style="color:chocolate"> Submission requirements </span>
#
# Additional points may be deducted if these requirements are not met:
#
# * Comment your code
# * Each graph should have a title, labels for each axis, and (if needed) a legend. Each graph should be understandable on its own
# * Be sure your submitted notebook includes the output of your run (Hint: go to Kernel -> Restart Kernel and Run All Cells...)
# * Try and minimize the use of the global namespace (meaning, keep things inside functions)
# * Upload your .ipynb file to Gradescope when done
# ---

# %% [markdown]
# #### ``Objectives``
# 1. Implement a CNN to detect diabetic retinopathy (DR) from retina images taken using fundus photography under a variety of imaging conditions
# 2. Improve generalization performance and reduce overfitting using **image transformation** and **data augmentation** techniques
# 3. Tune hyperparameters of the CNN model

# %% [markdown]
# #### ``Motivation``

# %% [markdown]
# Diabetic retinopathy (DR) is an eye condition that  affects blood vessels in the retina. It can cause vision loss and blindness in people who have diabetes. Screening for DR allows earlier and more effective treatment options for millions of people.

# %% [markdown]
# #### ``Data``

# %% [markdown]
# In this assignment you will use a small dataset of retina images (`Download` links: [images](https://drive.google.com/drive/folders/1sdfUC64Un1iwuiHEehcbijxB54OhU_nd?usp=sharing) and [labels](https://drive.google.com/drive/folders/1MOlSJBZg7L1HtG5vHPt77ighRvQaGfDg?usp=sharing)). You will **build** and **train** a **CNN model** to predict whether or not to refer a patient for DR treatment using binarized severity of DR in patients: no referral if {No DR, mild} and referral if {moderate, severe, and proliferate DR}.
#
#
# <u>Note</u>: the original dataset is hosted by Kaggle [[Source]](https://www.kaggle.com/c/aptos2019-blindness-detection/).

# %% [markdown]
# Import the necessary libraries and make sure to replace IMAGE_PATH and LABEL_PATH with the path to the directories where you saved the data.

# %%
# standard
import pandas as pd
import numpy as np
import random
import os

# tf and keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras import models
from keras import layers

# plots
import seaborn as sns
import matplotlib.pyplot as plt

random.seed(2)
# %matplotlib inline

# FILL IN CODE HERE #
from google.colab import drive
drive.mount('/content/drive')
IMAGE_PATH = '/content/drive/MyDrive/Colab Notebooks/Datasci 207/HW 10/CNN_images/' 
LABEL_PATH = '/content/drive/MyDrive/Colab Notebooks/Datasci 207/HW 10/CNN_labels/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# At this point, you may ask yourself what the best CNN model that fits this data is. First, you will want to read through the data description in Kaggle (see the link to the original dataset above). Understanding what you are working with challenges you to write preprocessing code that uncovers your data's most helpful information.

# %% [markdown]
# ---
# ### Exercise 1 (8 points)

# %% [markdown]
# Read the data description from Kaggle and list (a) the source of images and (b) the labeling procedure.

# %% [markdown]
# *Written answer*:
#
# (a) The source of images are retina images taken by fundus photography under various imaging conditions. These images were gathered from multiple medical clinics and cameras over an extended period of time.
#
# (b) Clinicians labelled each photograph by rating the severity of diabetic retinopathy in each image from 0-4, with 0 being no diabetic retinopathy and 4 being proliferative diabetic retinopathy

# %% [markdown]
# ---

# %% [markdown]
# ## Read data

# %% [markdown]
# Let's now explore our dataset. We will start with label inspection and continue with image visualization.

# %%
y = pd.read_csv(
    LABEL_PATH + 'labels.csv'
)

print('Shape of labels:', y.shape)
print('Unique diagnosis codes:', np.sort(y.diagnosis.unique()))
y.head()
# Out:
# Shape of labels: (200, 2)
# Unique diagnosis codes: [0 1 2 3 4]
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  0024cdab0c1e          1
# 2  0083ee8054ee          4
# 3  00a8624548a9          2
# 4  00b74780d31d          2

# %% [markdown]
# There are 200 training images corrresponding to 5 different diabetic retinopathy (DR) diagnosis codes:
#
# * No DR (0)
# * mild (1)
# * moderate (2)
# * severe (3)
# * proliferate DR (4)

# %% [markdown]
# Image inspection:

# %%
# read image
indx=0
images = []

print('Sample of images in data:')
for idx, img in enumerate(os.listdir(IMAGE_PATH)):
    img = load_img(
    IMAGE_PATH + img)
    images.append(img)

nrows, ncols = 2,4 #print first 8 images
f, axs = plt.subplots(nrows, ncols, figsize=(20,10))
for i in range(nrows):
    for j in range(ncols):
        indx = i*nrows+j
        axs[i,j].imshow(images[indx])
# Out:
# Sample of images in data:

# %% [markdown]
# Like any real-world data set, you can see that these images have different sizes and focus. Later, you will use image transformation and data augmentation techniques to remove some of this variation.

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# The quality of the data determines how well a machine learning algorithm can learn. This section will apply some simple techniques to deal with class imbalance. We will then create training/validation/test datasets and perform image transformation and augmentation.

# %% [markdown]
# ---
# ### Exercise 2 (8 points)

# %% [markdown]
# Graph a histogram for the five classes of DR. Write down the percentage of the largest class in the written answer below.

# %%
# YOUR CODE HERE
#plot histogram of the five classes of diabetic retinopathy
fig, ax  = plt.subplots(figsize = (10, 7))
ax.hist(y['diagnosis'], bins = [-0.5,  0.5,  1.5,  2.5,  3.5,  4.5])
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.title("Diabetic retinopathy class distribution")
plt.show()
#print the percentage of the largest class
print(y['diagnosis'].value_counts(normalize = True).max()* 100, "%")
# Out:
# 41.0 %

# %% [markdown]
# *Written answer*: The percentage of the largest class, 0, for no diabetic retinopathy, is 41.0%.
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# `Correct for data imbalance`

# %% [markdown]
# As you can see from the histogram above, our dataset is very imbalanced, which is common in healthcare, and it happens because some diseases are rare. The presence of imbalanced data hampers the detection of rare events as most classification methods implicitly assume a similar occurrence of classes and are designed to maximize the overall classification accuracy.
#
# We will correct for class imbalance in two ways:
#
#   * First, we will binarize the DR diagnosis as follows:
#      - 'no refer' are {No DR, mild}
#      - 'refer' are {Moderate, Severe, Proliferate}
#
#
#   * Second, we'll only take 80 random samples from the 'no refer' class and 80 from the 'refer' class.
#
# It is a crude method to deal with imbalanced data, but it will be good enough for this homework.

# %%
np.random.seed(1234)

no_refer = y[y.diagnosis.isin((0,1))]
refer = y[y.diagnosis.isin((2,3,4))]

# randomly draw 80 images from each classes
temp_no_refer = list(np.random.choice(
    no_refer.id_code,
    size=80,
    replace=False
))

temp_refer = list(np.random.choice(
    refer.id_code,
    size=80,
    replace=False
))

# %% [markdown]
# Next, we will use the **preprocess_data_part1()** function defined below to generate lists of images and labels (`images_mini` and `y_mini`) based on the values in the temp_no_refer and temp_refer lists.

# %%
def preprocess_data_part1(IMAGE_PATH, LABEL_PATH):
    """ Generate lists of images and labelsbased on temp_no_refer and temp_refer lists
    
    Params:
    -------
    IMAGE_PATH (str): path to directory with images.
    LABEL_PATH (str): path to directory with labels.
    
    Returns:
    --------
    images_mini  (np.ndarray): Images of shape (N, 224, 224, 3)
    y_mini (np.ndarray): Labels of shape (N,)    
    """
    y_mini = []
    images_mini = []

    # create lists of images and labels `images_mini` and `y_mini` 
    # based on temp_no_refer and temp_refer selections
    for idx, img in enumerate(os.listdir(IMAGE_PATH)):
        # read labels
        if img.split('.')[0] in temp_no_refer:
                y_mini.append(0)
        elif img.split('.')[0] in temp_refer:
                y_mini.append(1)
        else:
            continue

        
        # read image
        img = load_img(
            IMAGE_PATH + img,
            target_size=(224, 224)
        )
        
        # transform image to array
        img = img_to_array(img)

        # append to images
        images_mini.append(img)

    # stack images and trasnform to array
    images_mini = np.stack(images_mini)
    y_mini = np.array(y_mini).flatten() 
    
    return images_mini, y_mini

# %%
# generate images and labels based on preprocess_data_part1() function
images_mini, y_mini = preprocess_data_part1(IMAGE_PATH, LABEL_PATH)

print(f"images_mini shape {images_mini.shape}")
print(f"y_mini shape {y_mini.shape}")
# Out:
# images_mini shape (159, 224, 224, 3)
# y_mini shape (159,)

# %% [markdown]
# `Create train/validation/test data` and ``perform image tranformation and augmentation``

# %% [markdown]
# The next step in the data preprocessing part is to split the data into training, validation, and test sets. Once we have these partitions, we will apply image transformation and augmentations.
#
#
# To give you an idea of what image transformation and augmentation do, let's see an example applied to the first image in our mini data.

# %%
tf.random.set_seed(1234)

fig = plt.figure(figsize=(14, 12))

# pull first image from data
image = images_mini[0]

# plot original
ax = fig.add_subplot(1, 5, 1)
ax.imshow(array_to_img(image))
ax.set_title('Original', size=15);

# resize
ax = fig.add_subplot(1, 5, 2)
img_resize = tf.image.resize(image, size=(224, 224))
ax.imshow(array_to_img(img_resize))
ax.set_title('Step 1: Resize', size=15);


# adjust brightness
ax = fig.add_subplot(1, 5, 3)
img_bright = tf.image.adjust_brightness(img_resize, 0.3)
ax.imshow(array_to_img(img_bright))
ax.set_title('Step 2: Brightness', size=15);


# adjust contrast
ax = fig.add_subplot(1, 5, 4)
img_contrast = tf.image.adjust_contrast(img_bright, contrast_factor=3)
ax.imshow(array_to_img(img_contrast))
ax.set_title('Step 3: Contrast', size=15);


# flip left right
ax = fig.add_subplot(1, 5, 5)
img_flip = tf.image.flip_left_right(img_contrast)
ax.imshow(array_to_img(img_flip))
ax.set_title('Step 4: Flip left right', size=15);

# %% [markdown]
# Next, we will define and run the **preprocess_data_part2()** function to create:
#
# * train/validation/test sets with split (0.6,0.2,0.2)
#
# * image transformation and augmentation, as follows:
#
# <u>Applied on training, validation and test sets</u>:
#   - resize to IMAGE_SIZE =(224,224) using tf.image.resize()
#   - normalize all pixel values to the range (0,1)
#
# <u>Applied on training set only</u> (note that this step will create additional/augmented copies of the training data):
#   - adjust brightness by adding DELTA=0.3 to the pixel values using tf.image.adjust_brighness()
#   - adjust contrast to CONTRAST_FACTOR=3 using tf.image.adjust_contrast()
#   - flip left right using tf.image.flip_left_right()

# %% [markdown]
# The quantity and diversity of data gathered have a significant impact on the results of a CNN model. One can apply augmentations to artificially inflate the training dataset by warping the original data such that their label does not change. These augmentations can significantly improve learning results without collecting new data.

# %%
IMAGE_SIZE = (224, 224)
CONTRAST_FACTOR = 3
DELTA = 0.3

def preprocess_data_part2(images, y, split=(0.6,0.2,0.2)):
    """ Split data into train, validation and test sets; apply transformaions and augmentations
    
    Params:
    -------
    images  (np.ndarray): Images of shape (N, 224, 224, 3)
    y (np.ndarray): Labels of shape (N,)   
    split (tuple): 3 values summing to 1 defining split of train, validation and test sets
    
    Returns:
    --------
    X_train (np.ndarray): Train images of shape (N_train, 224, 224, 3)
    y_train (np.ndarray): Train labels of shape (N_train,)
    X_val (np.ndarray): Val images of shape (N_val, 224, 224, 3)
    y_val (np.ndarray): Val labels of shape (N_val,)
    X_test (np.ndarray): Test images of shape (N_test, 224, 224, 3)
    y_test (np.ndarray): Test labels of shape (N_test,)
    
    """
    
    ### create train/validation/test sets ###
    #########################################
    # NOTE: Each time you run this cell, you'll re-shuffle the data. The ordering will be the same due to the random seed generator 
    tf.random.set_seed(1234)
    np.random.seed(1234)
    shuffle = np.random.permutation(np.arange(images.shape[0]))
    images, y = images[shuffle], y[shuffle]
    
    splits = np.multiply(len(images_mini), split).astype(int)
    X_train, X_val, X_test = np.split(images_mini, [splits[0], splits[0]+splits[1]])
    y_train, y_val, y_test = np.split(y_mini, [splits[0], splits[0]+splits[1]])
    
    ### image transformation on training, validation, and test data ###
    ###################################################################
    # image resize
    X_train = tf.image.resize(X_train, size=IMAGE_SIZE)
    X_val = tf.image.resize(X_val, size=IMAGE_SIZE)
    X_test = tf.image.resize(X_test, size=IMAGE_SIZE)
    
    # rescale image to [0,1], i.e., greyscale
    X_train = X_train/255.0
    X_val = X_val/255.0
    X_test = X_test/255.0
    
    
    ### image augmentation on training data ###
    ###########################################
    # adjust brightness
    X_train_augm = tf.image.adjust_brightness(X_train, delta=DELTA)
    
    # adjust contrast
    X_train_augm = tf.image.adjust_contrast(X_train_augm, contrast_factor=CONTRAST_FACTOR)

    # random flip
    X_train_augm = tf.image.random_flip_left_right(X_train_augm)
    
    # concatenate original X_train and augmented X_train data
    X_train = tf.concat([X_train, X_train_augm],axis=0)
    
    # concatenate y_train (note the label is preserved)
    y_train_augm = y_train
    y_train = tf.concat([y_train, y_train_augm],axis=0)
    
    # shuffle X_train and y_train, i.e., shuffle two tensors in the same order
    shuffle = tf.random.shuffle(tf.range(tf.shape(X_train)[0], dtype=tf.int32))
    X_train = tf.gather(X_train, shuffle)
    y_train = tf.gather(y_train, shuffle).numpy() #also transforms y_train to numpy array
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# Let's sanity check our implementation of the preprocess_data_part2() function by printing the shape of (X,y) from train, validation and test sets.

# %%
X_train, y_train, X_val, y_val, X_test, y_test = preprocess_data_part2(
    images_mini,
    y_mini,
    split=(0.6,0.2,0.2)
)

print(f"X_train shape {X_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"X_val shape {X_val.shape}")
print(f"y_val shape {y_val.shape}")
print(f"X_test shape {X_test.shape}")
print(f"y_test shape {y_test.shape}")
# Out:
# X_train shape (190, 224, 224, 3)
# y_train shape (190,)
# X_val shape (31, 224, 224, 3)
# y_val shape (31,)
# X_test shape (33, 224, 224, 3)
# y_test shape (33,)

# %% [markdown]
# Let's also print out the first 8 train and validation examples with the label of each example as the title.

# %%
# print taining data
print('Print training data examples:')
nrows, ncols = 1,4 #print first 4 images
f, axs = plt.subplots(nrows, ncols, figsize=(14,12))
for i in range(ncols):
    axs[i].imshow(array_to_img(X_train[i]))
    axs[i].set(title=y_train[i])
# Out:
# Print training data examples:

# %%
# print test data
print('Print validation data examples:')
nrows, ncols = 1,4 #print first 4 images
f, axs = plt.subplots(nrows, ncols, figsize=(14,12))
for i in range(ncols):
    axs[i].imshow(array_to_img(X_val[i]))
    axs[i].set(title=y_val[i])
# Out:
# Print validation data examples:

# %% [markdown]
# ---
# ### Exercise 3 (8 points)
#
# We've split the data into train, validation, and test sets. Explain the purpose of each of these.

# %% [markdown]
# *Written answer*: The training dataset is designed to teach the model the relationship between the data (pixel values) and the class (refer or not refer). The model learns the CNN parameters which minimize the difference between predictions and values. Brighness, contrast and flip adjustments ensure that the training accurately captures the relationship between the images and their classes.
#
# The purpose of the validation dataset is to test the performance of the model during training and ensure that the model is not overfitting or underfitting. Validation scores help the model adjust its parameters after each epoch to better fit the data.
#
# The test data is used to evaluate the model's performance on unseen data. It is an estimate of how the model would fare in the real world.

# %% [markdown]
# ___

# %% [markdown]
# ## Model

# %% [markdown]
# Our objective is to build and train a CNN model to refer patients to doctors based on the severity of DR seen in these images. We are interested in exploring binary classification of 'no refer' and 'refer'.
#
# <u>The architecture of our CNN model is as follows</u>:
#
# 1. the model receives input images of size 224 x 224 x 3 (the images have three color channels)
# 2. the input data goes through two convolutional layers that have kernels of size 5 x 5
# 3. the first convolution has 32 output feature maps, and the second one has 64
# 4. each convolution layer is followed by a max-pooling layer (this will reduce the size of the feature maps)
# 5. the last two layers of the model are fully connected with a droput layer in between
#
# For each convolution we use strides=(1,1) to preserve the dimension of the inputs in the resulting feature maps. For the pooling layers, we set strides=(2,2) to subsample the image and shrink the size of the output feature maps. For the dropout layer, we set the probability of dropping input units during training to 0.5.
#
#
# We will implement this architecture using TensorFlow Keras API.

# %% [markdown]
# ``Build model``

# %%
model = tf.keras.Sequential()

# add first convolution layer to the model
model.add(tf.keras.layers.Conv2D(
    filters=32,
    kernel_size=(5, 5),
    strides=(1, 1),
    padding='same',
    data_format='channels_last',
    name='conv_1',
    activation='relu'))


# add a max pooling layer with pool size (2,2) and strides of 2
# (this will reduce the spatial dimensions by half)
model.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2),
    name='pool_1'))


# add second convolutional layer
model.add(tf.keras.layers.Conv2D(
    filters=64,
    kernel_size=(5, 5),
    strides=(1, 1),
    padding='same',
    name='conv_2',
    activation='relu'))

# add second max pooling layer with pool size (2,2) and strides of 2
# (this will further reduce the spatial dimensions by half)
model.add(tf.keras.layers.MaxPool2D(
    pool_size=(2, 2), name='pool_2')
)


# add a fully connected layer (need to flatten the output of the previous layers first)
model.add(tf.keras.layers.Flatten()) 
model.add(tf.keras.layers.Dense(
    units=1024,
    name='fc_1', 
    activation='relu'))

# add dropout layer
model.add(tf.keras.layers.Dropout(
    rate=0.5))

# add the last fully connected layer
# this last layer sets the activation function to "None" in order to output the logits 
# note that passing activation = "sigmoid" will return class memembership probabilities but
# in TensorFlow logits are prefered for numerical stability
# set units=1 to get a single output unit (remember it's a binary classification problem)
model.add(tf.keras.layers.Dense(
    units=1,
    name='fc_2',
    activation=None))


# build model and print summary
tf.random.set_seed(1)
model.build(input_shape=(None, 224, 224, 3))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 224, 224, 32)      2432
#
#  pool_1 (MaxPooling2D)       (None, 112, 112, 32)      0
#
#  conv_2 (Conv2D)             (None, 112, 112, 64)      51264
#
#  pool_2 (MaxPooling2D)       (None, 56, 56, 64)        0
#
#  flatten (Flatten)           (None, 200704)            0
#
#  fc_1 (Dense)                (None, 1024)              205521920
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 1)                 1025
#
# =================================================================
# Total params: 205,576,641
# Trainable params: 205,576,641
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ``Compile model``

# %% [markdown]
# The next step is to compile the model. We have to decide on the type of optimizer, loss function, and metrics to compute.
#
# We will use the Adam optimizer for this assignment, the most popular gradient-based optimization algorithm. There are a few other choices, and you can read more [here](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers). The loss (cost) function suitable for our binary classification model is [binary_crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses). We will compute model accuracy on the training, validation and test datasets.

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), #set from_ligits=True because our last layer does not apply sigmoid
              metrics=['accuracy'])

# %% [markdown]
# ``Fit model``

# %% [markdown]
# Finally, we will fit the model with 10 epochs on the train set and validate on the validation set. The performance depends on the current starter hyperparameters such as learning rate and choice of optimizer.

# %%
# set random seed to get reproductible results 
# neural network algorithms are stochastic (e.g., due to random weight initialization); setting a random seed helps to get more stable results after each run
# however, best way to deal with randomness is to repeat your experiment many times (30+) and use statistics to summarize the performance of the model
tf.random.set_seed(1234)
np.random.seed(1234)
history = model.fit(X_train, y_train,
                    epochs=10, 
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/10
# 6/6 [==============================] - 6s 299ms/step - loss: 7.3409 - accuracy: 0.5579 - val_loss: 0.5117 - val_accuracy: 0.4839
# Epoch 2/10
# 6/6 [==============================] - 1s 98ms/step - loss: 0.5079 - accuracy: 0.7368 - val_loss: 0.3470 - val_accuracy: 0.7097
# Epoch 3/10
# 6/6 [==============================] - 1s 100ms/step - loss: 0.4108 - accuracy: 0.8053 - val_loss: 0.3471 - val_accuracy: 0.6774
# Epoch 4/10
# 6/6 [==============================] - 1s 103ms/step - loss: 0.3593 - accuracy: 0.8263 - val_loss: 0.2959 - val_accuracy: 0.6774
# Epoch 5/10
# 6/6 [==============================] - 1s 105ms/step - loss: 0.3832 - accuracy: 0.8211 - val_loss: 0.2984 - val_accuracy: 0.6774
# Epoch 6/10
# 6/6 [==============================] - 1s 112ms/step - loss: 0.3148 - accuracy: 0.8316 - val_loss: 0.3035 - val_accuracy: 0.6774
# Epoch 7/10
# 6/6 [==============================] - 1s 103ms/step - loss: 0.3517 - accuracy: 0.8000 - val_loss: 0.3175 - val_accuracy: 0.6774
# Epoch 8/10
# 6/6 [==============================] - 1s 108ms/step - loss: 0.4112 - accuracy: 0.8000 - val_loss: 0.2651 - val_accuracy: 0.7742
# Epoch 9/10
# 6/6 [==============================] - 1s 107ms/step - loss: 0.3140 - accuracy: 0.8316 - val_loss: 0.3122 - val_accuracy: 0.6452
# Epoch 10/10
# 6/6 [==============================] - 1s 98ms/step - loss: 0.2939 - accuracy: 0.8368 - val_loss: 0.2451 - val_accuracy: 0.7742

# %% [markdown]
# Next let's plot loss and accuracy for training and validation sets

# %%
hist = history.history
x_arr = np.arange(len(hist['loss'])) + 1

fig = plt.figure(figsize=(12, 4))
ax = fig.add_subplot(1, 2, 1)
ax.plot(x_arr, hist['loss'], '-o', label='Train loss')
ax.plot(x_arr, hist['val_loss'], '--<', label='Validation loss')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Loss', size=15)

ax = fig.add_subplot(1, 2, 2)
ax.plot(x_arr, hist['accuracy'], '-o', label='Train acc.')
ax.plot(x_arr, hist['val_accuracy'], '--<', label='Validation acc.')
ax.legend(fontsize=15)
ax.set_xlabel('Epoch', size=15)
ax.set_ylabel('Accuracy', size=15)
plt.show()
tf.keras.backend.clear_session()

# %% [markdown]
# ## Show what the CNN model is learning after each layer

# %% [markdown]
# We will pick one example from our training data to visualize our CNN model's learning after each layer. Below we print the original image.

# %%
img_tensor = np.expand_dims(X_train[2], axis = 0);

# Print image tensor shape
print('Shape of image:', img_tensor.shape);
  
# Print image
plt.imshow(img_tensor[0]);
plt.title('label:' + str(y_train[1]))
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Shape of image: (1, 224, 224, 3)

# %% [markdown]
# Next we print what the model learns after each layer-channel. It's important to pay attention to the shape of the output image to understand what each layer does to the original input.

# %%
# outputs of the first 4 layers, which include conv2D and max pooling layers
layer_outputs = [layer.output for layer in model.layers[:4]]
activation_model = models.Model(inputs = model.input, outputs = layer_outputs)
activations = activation_model.predict(img_tensor)

# grab layer names
layer_names = []
for layer in model.layers[:4]:
    layer_names.append(layer.name)

# getting activations of each layer
for idx, layer in enumerate(activations):
    if idx in (0,1,2,3):
        print('----------------')
        print('Geeting activations of layer',  idx+1, ':', layer_names[idx])
        activation = layer

        # shape of layer activation
        print('Images size is', activation.shape[1], 'x', activation.shape[2])
        print('Number of channels is', activation.shape[3])

        # print channels
        print('Printing channels:')
        
        # define nrows and ncols depending on number of channels
        if idx in (0,1):
            nrows, ncols = 4,8
        if idx in (2,3):
            nrows, ncols = 8,8

        # plots
        channel=0
        if idx in (0,1):
            f, axs = plt.subplots(nrows, ncols, figsize=(14,12))
        if idx in (2,3):
            f, axs = plt.subplots(nrows, ncols, figsize=(14,20))
            
        for i in range(nrows):
            for j in range(ncols):
                if i==0 and j==0:
                    channel=0
                else:
                    channel+=1

                axs[i,j].matshow(activation[0,:, :, channel], cmap ='viridis')
                axs[i,j].set(title=str(channel))
                #axs[i,j].axis('off') # pay attention to the range of x and y axis
        plt.show()
# Out:
# 1/1 [==============================] - 0s 118ms/step
# ----------------
# Geeting activations of layer 1 : conv_1
# Images size is 224 x 224
# Number of channels is 32
# Printing channels:
# ----------------
# Geeting activations of layer 2 : pool_1
# Images size is 112 x 112
# Number of channels is 32
# Printing channels:
# ----------------
# Geeting activations of layer 3 : conv_2
# Images size is 112 x 112
# Number of channels is 64
# Printing channels:
# ----------------
# Geeting activations of layer 4 : pool_2
# Images size is 56 x 56
# Number of channels is 64
# Printing channels:

# %% [markdown]
# As you can see, initial layers are more interpretable and retain the majority of the features in the input image. As the level of the layer increases, features become less interpretable, they become more abstract and they identify features specific to the class leaving behind the general features of the image.

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Evaluation is one of the most important parts of machine learning as it helps us determine how good our trained model is in predicting unseen data.
#
# Notice that (`X_test`, and `y_test`) were not used in the training part. It would be very bad practice to evaluate the model on the test set, and then return and update the model based on those results (then the test set is acting like just another validation set).

# %% [markdown]
# We will now use our test data to evaluate the performance (accuracy) of our CNN model on unseen data. Note that accuracy is the default metric if one compiles the model with the accuracy metric.

# %%
test_results = model.evaluate(X_test, y_test)
print('\nTest Acc. {:.2f}%'.format(test_results[1]*100))
# Out:
# 2/2 [==============================] - 0s 47ms/step - loss: 0.4136 - accuracy: 0.9091
#
# Test Acc. 90.91%

# %% [markdown]
# `get predictions results in the form of class-membership probabilities`

# %% [markdown]
# In the following figure, you can see all the images in the test data along with their ground truth (GT) labels and the predicted probabiliy that they belong to class 1, 'Refer'

# %%
# transform logits to probabilities
pred_logits = model.predict(X_test)
probas = tf.sigmoid(pred_logits)
probas = probas.numpy().flatten()*100
# Out:
# 2/2 [==============================] - 0s 18ms/step

# %%
# plot test data and associated predicred
fig = plt.figure(figsize=(20, 20))

for j, example in enumerate(X_test):
    ax = fig.add_subplot(9,4, j+1)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow(array_to_img(example))
    if y_test[j]==0:
        label='no refer'
    else:
        label='refer'
    
    ax.text(
        0.5, -0.15, 
        'GT: {:s}\nPr(refer)={:.0f}%'.format(label, probas[j]), 
        size=16, 
        color='grey',
        horizontalalignment='center',
        verticalalignment='center', 
        transform=ax.transAxes)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ### Exercise 4 (8 points)

# %% [markdown]
# In this exercise, your task is to experiment with different hyperparameter values to see how sensitive the accuracy of our CNN model is.  In the table below, you will fill in `training and validation accuracy` results corresponding to the last epoch of the model fit.
#
# You will change one hyperparameter value at a time, as follows:
#
# * kernel size = 3 x 3
# * strides = 2 x 2
# * pool size = 3 x 3
# * learning rate = 0.01
# * optimizer = 'SGD'
# * image augmentation applied on the training data: (brightness (delta) = 0.1, contrast = 2, flip = no)
#
# Finally, comment on the CNN model specification that you are most satisfied with based on the accuracy achieved on the training and validation sets. For this specification, what is the accuracy of the test dataset?

# %% [markdown]
# *Written answer*:
#
# | Training accuracy | Validation accuracy |  kernel size |  strides | pool size  |  learning rate | optimizer  | brightness (delta) |  contrast factor | flip_on_train  |
# |:-:                |:-:                  |:-:           |:-:       |:-:         |:-:             |:-:         |:-:                 |:-:               |:-:             |
# |             .84 |             .77 | 5,5          | 1,1      | 2,2        | 0.001          | Adam       | 0.3                | 3                | yes            |
# | .99              | .71                 | <font color="red">3,3</font>     | 1,1      | 2,2        | 0.001          | Adam       | 0.3                | 3                | yes            |
# | .90              | .87                | 5,5          | <font color="red">2,2</font>  | 2,2        | 0.001          | Adam       | 0.3                | 3                | yes            |
# | .85              | .68                 | 5,5          | 1,1      | <font color="red">3,3</font>   | 0.001          | Adam       | 0.3                | 3                | yes            |
# | .53             | .42                 | 5,5          | 1,1      | 2,2        | <font color="red">0.01</font>       | Adam       | 0.3                | 3                | yes            |
# | .59              | .42              | 5,5          | 1,1      | 2,2        | 0.001          |<font color="red">SGD</font>     | 0.3                | 3                | yes            |
# | .91               | .68                 | 5,5          | 1,1      | 2,2        | 0.001          | Adam       | <font color="red">0.1</font>            | 3                | yes            |
# | .91               | .68                 | 5,5          | 1,1      | 2,2        | 0.001          | Adam       | 0.3                | <font color="red">2</font>            | yes            |
# | .96              | .71                | 5,5          | 1,1      | 2,2        | 0.001          | Adam       | 0.3                | 3                | <font color="red">no</font>         |

# %% [markdown]
# I am most satisfied on the model with (2,2) strides. It achieves trainining accuracy of .90 and validation accuracy of .87.The accuracy on the test dataset is .88.

# %% [markdown]
# Define adjustable preprocessing function

# %%
def preprocess_data_part2_custom(images, y, split=(0.6,0.2,0.2), delta = 0.3, contrast_factor = 3, flip_on_train = True):
    ### create train/validation/test sets ###
    #########################################
    # NOTE: Each time you run this cell, you'll re-shuffle the data. The ordering will be the same due to the random seed generator 
    tf.random.set_seed(1234)
    np.random.seed(1234)
    shuffle = np.random.permutation(np.arange(images.shape[0]))
    images, y = images[shuffle], y[shuffle]
    
    splits = np.multiply(len(images_mini), split).astype(int)
    X_train, X_val, X_test = np.split(images_mini, [splits[0], splits[0]+splits[1]])
    y_train, y_val, y_test = np.split(y_mini, [splits[0], splits[0]+splits[1]])
    
    ### image transformation on training, validation, and test data ###
    ###################################################################
    # image resize
    X_train = tf.image.resize(X_train, size=IMAGE_SIZE)
    X_val = tf.image.resize(X_val, size=IMAGE_SIZE)
    X_test = tf.image.resize(X_test, size=IMAGE_SIZE)
    
    # rescale image to [0,1], i.e., greyscale
    X_train = X_train/255.0
    X_val = X_val/255.0
    X_test = X_test/255.0
    
    
    ### image augmentation on training data ###
    ###########################################
    # adjust brightness
    X_train_augm = tf.image.adjust_brightness(X_train, delta=DELTA)
    
    # adjust contrast
    X_train_augm = tf.image.adjust_contrast(X_train_augm, contrast_factor=contrast_factor)

    # random flip
    if flip_on_train == True:
      X_train_augm = tf.image.random_flip_left_right(X_train_augm)
    
    # concatenate original X_train and augmented X_train data
    X_train = tf.concat([X_train, X_train_augm],axis=0)
    
    # concatenate y_train (note the label is preserved)
    y_train_augm = y_train
    y_train = tf.concat([y_train, y_train_augm],axis=0)
    
    # shuffle X_train and y_train, i.e., shuffle two tensors in the same order
    shuffle = tf.random.shuffle(tf.range(tf.shape(X_train)[0], dtype=tf.int32))
    X_train = tf.gather(X_train, shuffle)
    y_train = tf.gather(y_train, shuffle).numpy() #also transforms y_train to numpy array
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# Define adjustable model creation function

# %%
def create_model( X_train = X_train, y_train = y_train, X_test = X_test, y_test = y_test, X_val = X_val, y_val = y_val, kernel_size = (5, 5), strides = (1,1), pool_size = (2, 2), learning_rate = 0.001, optimizer = 'Adam', delta = 0.3, contrast_factor = 3, flip_on_train = True, batch_size = 8):
  #clear memory
  tf.keras.backend.clear_session()

  #initialize model
  model = tf.keras.Sequential()

  # add first convolution layer to the model
  model.add(tf.keras.layers.Conv2D(
      filters=32,
      kernel_size=kernel_size,
      strides=strides,
      padding='same',
      data_format='channels_last',
      name='conv_1',
      activation='relu'))


  # add a max pooling layer with pool size (2,2) and strides of 2
  # (this will reduce the spatial dimensions by half)
  model.add(tf.keras.layers.MaxPool2D(
      pool_size=pool_size,
      name='pool_1'))


  # add second convolutional layer
  model.add(tf.keras.layers.Conv2D(
      filters=64,
      kernel_size=kernel_size,
      strides=strides,
      padding='same',
      name='conv_2',
      activation='relu'))

  # add second max pooling layer with pool size (2,2) and strides of 2
  # (this will further reduce the spatial dimensions by half)
  model.add(tf.keras.layers.MaxPool2D(
      pool_size=pool_size, name='pool_2')
  )


  # add a fully connected layer (need to flatten the output of the previous layers first)
  model.add(tf.keras.layers.Flatten()) 
  model.add(tf.keras.layers.Dense(
      units=1024,
      name='fc_1', 
      activation='relu'))

  # add dropout layer
  model.add(tf.keras.layers.Dropout(
      rate=0.5))

  # add the last fully connected layer
  # this last layer sets the activation function to "None" in order to output the logits 
  # note that passing activation = "sigmoid" will return class memembership probabilities but
  # in TensorFlow logits are prefered for numerical stability
  # set units=1 to get a single output unit (remember it's a binary classification problem)
  model.add(tf.keras.layers.Dense(
      units=1,
      name='fc_2',
      activation=None))

  # build model and print summary
  tf.random.set_seed(1)
  model.build(input_shape=(None, 224, 224, 3))
  model.summary()

  #Compile model
  if optimizer == 'Adam':
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = learning_rate),
                  loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), #set from_logits=True because our last layer does not apply sigmoid
                  metrics=['accuracy'])
  elif optimizer == 'SGD':
        model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate = learning_rate),
                  loss=tf.keras.losses.BinaryCrossentropy(from_logits=True), #set from_logits=True because our last layer does not apply sigmoid
                  metrics=['accuracy']) 


  #Set up custom processed datasets
  if (not delta == 0.3) or (not contrast_factor == 3 ) or (not flip_on_train) :
    print("Reprocessing data")
    X_train, y_train, X_val, y_val, X_test, y_test = preprocess_data_part2_custom(
          images_mini,
          y_mini,
          split=(0.6,0.2,0.2), 
          delta = delta, 
          contrast_factor = contrast_factor,
          flip_on_train = flip_on_train
      )

  # set random seed to get reproductible results 
  # neural network algorithms are stochastic (e.g., due to random weight initialization); setting a random seed helps to get more stable results after each run
  # however, best way to deal with randomness is to repeat your experiment many times (30+) and use statistics to summarize the performance of the model
  tf.random.set_seed(1234)
  np.random.seed(1234)
  history = model.fit(X_train, y_train,
                      epochs=10, 
                      validation_data=(X_val, y_val),
                      batch_size = 32
  )

  #Plot loss and accuracy for training and validation sets
  hist = history.history
  x_arr = np.arange(len(hist['loss'])) + 1

  fig = plt.figure(figsize=(12, 4))
  ax = fig.add_subplot(1, 2, 1)
  ax.plot(x_arr, hist['loss'], '-o', label='Train loss')
  ax.plot(x_arr, hist['val_loss'], '--<', label='Validation loss')
  ax.legend(fontsize=15)
  ax.set_xlabel('Epoch', size=15)
  ax.set_ylabel('Loss', size=15)

  ax = fig.add_subplot(1, 2, 2)
  ax.plot(x_arr, hist['accuracy'], '-o', label='Train acc.')
  ax.plot(x_arr, hist['val_accuracy'], '--<', label='Validation acc.')
  ax.legend(fontsize=15)
  ax.set_xlabel('Epoch', size=15)
  ax.set_ylabel('Accuracy', size=15)
  plt.show()

  #Print out training and validation accuracy
  print("Training accuracy: ", model.evaluate(X_train, y_train)[1])
  print("Validation accuracy: ", model.evaluate(X_val, y_val)[1])
  #clear memory
  tf.keras.backend.clear_session()
  return model

# %% [markdown]
# Run models with different hyperparameters

# %%
#Create base model without changing hyperparameters
print("Creating base model")
base_model = create_model()
# Out:
# Creating base model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 224, 224, 32)      2432
#
#  pool_1 (MaxPooling2D)       (None, 112, 112, 32)      0
#
#  conv_2 (Conv2D)             (None, 112, 112, 64)      51264
#
#  pool_2 (MaxPooling2D)       (None, 56, 56, 64)        0
#
#  flatten (Flatten)           (None, 200704)            0
#
#  fc_1 (Dense)                (None, 1024)              205521920
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 1)                 1025
#
# =================================================================
# Total params: 205,576,641
# Trainable params: 205,576,641
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 6/6 [==============================] - 3s 168ms/step - loss: 5.9559 - accuracy: 0.5579 - val_loss: 0.5395 - val_accuracy: 0.4839
# Epoch 2/10
# 6/6 [==============================] - 1s 101ms/step - loss: 0.4875 - accuracy: 0.7579 - val_loss: 0.4415 - val_accuracy: 0.6774
# Epoch 3/10
# 6/6 [==============================] - 1s 109ms/step - loss: 0.4436 - accuracy: 0.7842 - val_loss: 0.3415 - val_accuracy: 0.6774
# Epoch 4/10
# 6/6 [==============================] - 1s 99ms/step - loss: 0.3827 - accuracy: 0.8158 - val_loss: 0.3294 - val_accuracy: 0.6774
# Epoch 5/10
# 6/6 [==============================] - 1s 99ms/step - loss: 0.3305 - accuracy: 0.8316 - val_loss: 0.2681 - val_accuracy: 0.7742
# Epoch 6/10
# 6/6 [==============================] - 1s 100ms/step - loss: 0.2961 - accuracy: 0.8579 - val_loss: 0.2882 - val_accuracy: 0.7742
# Epoch 7/10
# 6/6 [==============================] - 1s 100ms/step - loss: 0.3909 - accuracy: 0.7842 - val_loss: 0.3547 - val_accuracy: 0.9355
# Epoch 8/10
# 6/6 [==============================] - 1s 100ms/step - loss: 1.0893 - accuracy: 0.7368 - val_loss: 0.8792 - val_accuracy: 0.6129
# Epoch 9/10
# 6/6 [==============================] - 1s 97ms/step - loss: 0.5018 - accuracy: 0.8263 - val_loss: 0.2475 - val_accuracy: 0.7419
# Epoch 10/10
# 6/6 [==============================] - 1s 98ms/step - loss: 0.3939 - accuracy: 0.8316 - val_loss: 0.3190 - val_accuracy: 0.7742
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3810 - accuracy: 0.8421
# Training accuracy:  0.8421052694320679
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3190 - accuracy: 0.7742
# Validation accuracy:  0.774193525314331

# %%
print("Creating model with kernel size (3,3)")
kernel_model = create_model(kernel_size = (3,3))
# Out:
# Creating model with kernel size (3,3)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 224, 224, 32)      896
#
#  pool_1 (MaxPooling2D)       (None, 112, 112, 32)      0
#
#  conv_2 (Conv2D)             (None, 112, 112, 64)      18496
#
#  pool_2 (MaxPooling2D)       (None, 56, 56, 64)        0
#
#  flatten (Flatten)           (None, 200704)            0
#
#  fc_1 (Dense)                (None, 1024)              205521920
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 1)                 1025
#
# =================================================================
# Total params: 205,542,337
# Trainable params: 205,542,337
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 6/6 [==============================] - 3s 221ms/step - loss: 8.2934 - accuracy: 0.5526 - val_loss: 2.7183 - val_accuracy: 0.4194
# Epoch 2/10
# 6/6 [==============================] - 1s 86ms/step - loss: 1.5790 - accuracy: 0.6947 - val_loss: 0.5850 - val_accuracy: 0.5484
# Epoch 3/10
# 6/6 [==============================] - 1s 87ms/step - loss: 0.4847 - accuracy: 0.7579 - val_loss: 0.3421 - val_accuracy: 0.6774
# Epoch 4/10
# 6/6 [==============================] - 1s 87ms/step - loss: 0.3676 - accuracy: 0.7895 - val_loss: 0.2835 - val_accuracy: 0.7097
# Epoch 5/10
# 6/6 [==============================] - 1s 101ms/step - loss: 0.3057 - accuracy: 0.8316 - val_loss: 0.2266 - val_accuracy: 0.8710
# Epoch 6/10
# 6/6 [==============================] - 1s 96ms/step - loss: 0.2563 - accuracy: 0.8842 - val_loss: 0.3980 - val_accuracy: 0.7097
# Epoch 7/10
# 6/6 [==============================] - 1s 95ms/step - loss: 0.2369 - accuracy: 0.8947 - val_loss: 0.3310 - val_accuracy: 0.7419
# Epoch 8/10
# 6/6 [==============================] - 1s 97ms/step - loss: 0.2015 - accuracy: 0.9316 - val_loss: 0.5149 - val_accuracy: 0.6774
# Epoch 9/10
# 6/6 [==============================] - 1s 90ms/step - loss: 0.1295 - accuracy: 0.9579 - val_loss: 0.3475 - val_accuracy: 0.7097
# Epoch 10/10
# 6/6 [==============================] - 1s 98ms/step - loss: 0.1243 - accuracy: 0.9474 - val_loss: 0.3142 - val_accuracy: 0.7097
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0683 - accuracy: 0.9895
# Training accuracy:  0.9894737005233765
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3142 - accuracy: 0.7097
# Validation accuracy:  0.7096773982048035

# %%
#Set strides to 2,2
print("Creating model with strides (2,2)")
stride_model = create_model(strides = (2,2))
# Out:
# Creating model with strides (2,2)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 112, 112, 32)      2432
#
#  pool_1 (MaxPooling2D)       (None, 56, 56, 32)        0
#
#  conv_2 (Conv2D)             (None, 28, 28, 64)        51264
#
#  pool_2 (MaxPooling2D)       (None, 14, 14, 64)        0
#
#  flatten (Flatten)           (None, 12544)             0
#
#  fc_1 (Dense)                (None, 1024)              12846080
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 1)                 1025
#
# =================================================================
# Total params: 12,900,801
# Trainable params: 12,900,801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 6/6 [==============================] - 2s 121ms/step - loss: 1.0585 - accuracy: 0.5474 - val_loss: 0.6735 - val_accuracy: 0.4194
# Epoch 2/10
# 6/6 [==============================] - 0s 71ms/step - loss: 0.6792 - accuracy: 0.5789 - val_loss: 0.6656 - val_accuracy: 0.4194
# Epoch 3/10
# 6/6 [==============================] - 0s 62ms/step - loss: 0.5907 - accuracy: 0.6421 - val_loss: 0.5378 - val_accuracy: 0.6452
# Epoch 4/10
# 6/6 [==============================] - 0s 39ms/step - loss: 0.4945 - accuracy: 0.7316 - val_loss: 0.4603 - val_accuracy: 0.6774
# Epoch 5/10
# 6/6 [==============================] - 0s 36ms/step - loss: 0.4451 - accuracy: 0.7842 - val_loss: 0.3955 - val_accuracy: 0.7097
# Epoch 6/10
# 6/6 [==============================] - 0s 41ms/step - loss: 0.4084 - accuracy: 0.7842 - val_loss: 0.4140 - val_accuracy: 0.6774
# Epoch 7/10
# 6/6 [==============================] - 0s 39ms/step - loss: 0.4045 - accuracy: 0.7789 - val_loss: 0.3894 - val_accuracy: 0.6774
# Epoch 8/10
# 6/6 [==============================] - 0s 39ms/step - loss: 0.3919 - accuracy: 0.8158 - val_loss: 0.4516 - val_accuracy: 0.6774
# Epoch 9/10
# 6/6 [==============================] - 0s 38ms/step - loss: 0.3418 - accuracy: 0.8053 - val_loss: 0.3430 - val_accuracy: 0.6774
# Epoch 10/10
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3503 - accuracy: 0.8211 - val_loss: 0.2954 - val_accuracy: 0.8710
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3005 - accuracy: 0.9000
# Training accuracy:  0.8999999761581421
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2954 - accuracy: 0.8710
# Validation accuracy:  0.8709677457809448

# %%
#Set pool size to 3,3 
print("Creating model with pool size (3,3)")
pool_model = create_model(pool_size = (3,3))
# Out:
# Creating model with pool size (3,3)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 224, 224, 32)      2432
#
#  pool_1 (MaxPooling2D)       (None, 74, 74, 32)        0
#
#  conv_2 (Conv2D)             (None, 74, 74, 64)        51264
#
#  pool_2 (MaxPooling2D)       (None, 24, 24, 64)        0
#
#  flatten (Flatten)           (None, 36864)             0
#
#  fc_1 (Dense)                (None, 1024)              37749760
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 1)                 1025
#
# =================================================================
# Total params: 37,804,481
# Trainable params: 37,804,481
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 6/6 [==============================] - 3s 146ms/step - loss: 3.0350 - accuracy: 0.5526 - val_loss: 0.6178 - val_accuracy: 0.5806
# Epoch 2/10
# 6/6 [==============================] - 0s 70ms/step - loss: 0.5792 - accuracy: 0.6789 - val_loss: 0.4583 - val_accuracy: 0.7742
# Epoch 3/10
# 6/6 [==============================] - 0s 57ms/step - loss: 0.4733 - accuracy: 0.7474 - val_loss: 0.4015 - val_accuracy: 0.7419
# Epoch 4/10
# 6/6 [==============================] - 0s 57ms/step - loss: 0.4255 - accuracy: 0.7947 - val_loss: 0.3925 - val_accuracy: 0.6774
# Epoch 5/10
# 6/6 [==============================] - 0s 57ms/step - loss: 0.4189 - accuracy: 0.7789 - val_loss: 0.3413 - val_accuracy: 0.7097
# Epoch 6/10
# 6/6 [==============================] - 0s 56ms/step - loss: 0.3838 - accuracy: 0.8211 - val_loss: 0.3470 - val_accuracy: 0.6774
# Epoch 7/10
# 6/6 [==============================] - 0s 57ms/step - loss: 0.3756 - accuracy: 0.8000 - val_loss: 0.2942 - val_accuracy: 0.6774
# Epoch 8/10
# 6/6 [==============================] - 0s 67ms/step - loss: 0.4124 - accuracy: 0.7947 - val_loss: 0.3621 - val_accuracy: 0.6774
# Epoch 9/10
# 6/6 [==============================] - 0s 54ms/step - loss: 0.3602 - accuracy: 0.8368 - val_loss: 0.3039 - val_accuracy: 0.7097
# Epoch 10/10
# 6/6 [==============================] - 0s 55ms/step - loss: 0.3374 - accuracy: 0.8316 - val_loss: 0.3057 - val_accuracy: 0.6774
# 6/6 [==============================] - 0s 16ms/step - loss: 0.3038 - accuracy: 0.8526
# Training accuracy:  0.8526315689086914
# 1/1 [==============================] - 0s 40ms/step - loss: 0.3057 - accuracy: 0.6774
# Validation accuracy:  0.6774193644523621

# %%
#Set learning rate to 0.01 
print("Creating model with learning rate 0.01")
lr_model = create_model(learning_rate = 0.01, batch_size = 16)
# Out:
# Creating model with learning rate 0.01
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 224, 224, 32)      2432
#
#  pool_1 (MaxPooling2D)       (None, 112, 112, 32)      0
#
#  conv_2 (Conv2D)             (None, 112, 112, 64)      51264
#
#  pool_2 (MaxPooling2D)       (None, 56, 56, 64)        0
#
#  flatten (Flatten)           (None, 200704)            0
#
#  fc_1 (Dense)                (None, 1024)              205521920
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 1)                 1025
#
# =================================================================
# Total params: 205,576,641
# Trainable params: 205,576,641
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 6/6 [==============================] - 6s 277ms/step - loss: 169.1914 - accuracy: 0.5316 - val_loss: 0.6933 - val_accuracy: 0.4194
# Epoch 2/10
# 6/6 [==============================] - 1s 96ms/step - loss: 0.6919 - accuracy: 0.5263 - val_loss: 0.6988 - val_accuracy: 0.4194
# Epoch 3/10
# 6/6 [==============================] - 1s 95ms/step - loss: 0.7057 - accuracy: 0.5263 - val_loss: 0.7021 - val_accuracy: 0.4194
# Epoch 4/10
# 6/6 [==============================] - 1s 102ms/step - loss: 0.6921 - accuracy: 0.5263 - val_loss: 0.7015 - val_accuracy: 0.4194
# Epoch 5/10
# 6/6 [==============================] - 1s 102ms/step - loss: 0.6945 - accuracy: 0.5263 - val_loss: 0.7028 - val_accuracy: 0.4194
# Epoch 6/10
# 6/6 [==============================] - 1s 109ms/step - loss: 0.6906 - accuracy: 0.5263 - val_loss: 0.7035 - val_accuracy: 0.4194
# Epoch 7/10
# 6/6 [==============================] - 1s 99ms/step - loss: 0.6938 - accuracy: 0.5263 - val_loss: 0.7062 - val_accuracy: 0.4194
# Epoch 8/10
# 6/6 [==============================] - 1s 107ms/step - loss: 0.6931 - accuracy: 0.5263 - val_loss: 0.7017 - val_accuracy: 0.4194
# Epoch 9/10
# 6/6 [==============================] - 1s 105ms/step - loss: 0.6920 - accuracy: 0.5263 - val_loss: 0.7030 - val_accuracy: 0.4194
# Epoch 10/10
# 6/6 [==============================] - 1s 101ms/step - loss: 0.6928 - accuracy: 0.5263 - val_loss: 0.7021 - val_accuracy: 0.4194
# 6/6 [==============================] - 0s 22ms/step - loss: 0.6915 - accuracy: 0.5263
# Training accuracy:  0.5263158082962036
# 1/1 [==============================] - 0s 45ms/step - loss: 0.7021 - accuracy: 0.4194
# Validation accuracy:  0.4193548262119293

# %%
#Set optimizer to SGD 
print("Creating model with SGD optimizer")
sgd_model = create_model(optimizer = "SGD")
# Out:
# Creating model with SGD optimizer
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 224, 224, 32)      2432
#
#  pool_1 (MaxPooling2D)       (None, 112, 112, 32)      0
#
#  conv_2 (Conv2D)             (None, 112, 112, 64)      51264
#
#  pool_2 (MaxPooling2D)       (None, 56, 56, 64)        0
#
#  flatten (Flatten)           (None, 200704)            0
#
#  fc_1 (Dense)                (None, 1024)              205521920
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 1)                 1025
#
# =================================================================
# Total params: 205,576,641
# Trainable params: 205,576,641
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 6/6 [==============================] - 2s 129ms/step - loss: 0.6875 - accuracy: 0.5263 - val_loss: 0.6846 - val_accuracy: 0.4194
# Epoch 2/10
# 6/6 [==============================] - 1s 89ms/step - loss: 0.6692 - accuracy: 0.5211 - val_loss: 0.6834 - val_accuracy: 0.4194
# Epoch 3/10
# 6/6 [==============================] - 1s 88ms/step - loss: 0.6600 - accuracy: 0.5263 - val_loss: 0.6675 - val_accuracy: 0.4194
# Epoch 4/10
# 6/6 [==============================] - 1s 96ms/step - loss: 0.6428 - accuracy: 0.5368 - val_loss: 0.6637 - val_accuracy: 0.4194
# Epoch 5/10
# 6/6 [==============================] - 1s 97ms/step - loss: 0.6378 - accuracy: 0.5368 - val_loss: 0.6548 - val_accuracy: 0.4194
# Epoch 6/10
# 6/6 [==============================] - 1s 89ms/step - loss: 0.6189 - accuracy: 0.5474 - val_loss: 0.6503 - val_accuracy: 0.4194
# Epoch 7/10
# 6/6 [==============================] - 1s 96ms/step - loss: 0.6187 - accuracy: 0.5368 - val_loss: 0.6352 - val_accuracy: 0.4194
# Epoch 8/10
# 6/6 [==============================] - 1s 88ms/step - loss: 0.6121 - accuracy: 0.5947 - val_loss: 0.6389 - val_accuracy: 0.4194
# Epoch 9/10
# 6/6 [==============================] - 1s 88ms/step - loss: 0.5950 - accuracy: 0.5579 - val_loss: 0.6267 - val_accuracy: 0.4194
# Epoch 10/10
# 6/6 [==============================] - 1s 91ms/step - loss: 0.5975 - accuracy: 0.5526 - val_loss: 0.6226 - val_accuracy: 0.4194
# 6/6 [==============================] - 0s 29ms/step - loss: 0.5825 - accuracy: 0.5947
# Training accuracy:  0.5947368144989014
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6226 - accuracy: 0.4194
# Validation accuracy:  0.4193548262119293

# %%
#Set brightness delta to 0.1 
print("Creating model with 0.1 brightness delta")
brightness_model = create_model(delta = 0.1)
# Out:
# Creating model with 0.1 brightness delta
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 224, 224, 32)      2432
#
#  pool_1 (MaxPooling2D)       (None, 112, 112, 32)      0
#
#  conv_2 (Conv2D)             (None, 112, 112, 64)      51264
#
#  pool_2 (MaxPooling2D)       (None, 56, 56, 64)        0
#
#  flatten (Flatten)           (None, 200704)            0
#
#  fc_1 (Dense)                (None, 1024)              205521920
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 1)                 1025
#
# =================================================================
# Total params: 205,576,641
# Trainable params: 205,576,641
# Non-trainable params: 0
# _________________________________________________________________
# Reprocessing data
# Epoch 1/10
# 6/6 [==============================] - 2s 142ms/step - loss: 10.5087 - accuracy: 0.5368 - val_loss: 0.4949 - val_accuracy: 0.4839
# Epoch 2/10
# 6/6 [==============================] - 1s 106ms/step - loss: 0.6874 - accuracy: 0.6368 - val_loss: 0.4318 - val_accuracy: 0.6452
# Epoch 3/10
# 6/6 [==============================] - 1s 107ms/step - loss: 0.4209 - accuracy: 0.7789 - val_loss: 0.3621 - val_accuracy: 0.6774
# Epoch 4/10
# 6/6 [==============================] - 1s 101ms/step - loss: 0.3960 - accuracy: 0.8053 - val_loss: 0.5161 - val_accuracy: 0.6774
# Epoch 5/10
# 6/6 [==============================] - 1s 108ms/step - loss: 0.3547 - accuracy: 0.8421 - val_loss: 0.3155 - val_accuracy: 0.6774
# Epoch 6/10
# 6/6 [==============================] - 1s 105ms/step - loss: 0.3070 - accuracy: 0.8579 - val_loss: 0.3751 - val_accuracy: 0.6774
# Epoch 7/10
# 6/6 [==============================] - 1s 104ms/step - loss: 0.3517 - accuracy: 0.8000 - val_loss: 0.3814 - val_accuracy: 0.6452
# Epoch 8/10
# 6/6 [==============================] - 1s 96ms/step - loss: 0.3210 - accuracy: 0.8263 - val_loss: 0.3100 - val_accuracy: 0.7097
# Epoch 9/10
# 6/6 [==============================] - 1s 95ms/step - loss: 0.2946 - accuracy: 0.8579 - val_loss: 0.3157 - val_accuracy: 0.6452
# Epoch 10/10
# 6/6 [==============================] - 1s 95ms/step - loss: 0.2677 - accuracy: 0.8684 - val_loss: 0.3517 - val_accuracy: 0.6774
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2261 - accuracy: 0.9053
# Training accuracy:  0.9052631855010986
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3517 - accuracy: 0.6774
# Validation accuracy:  0.6774193644523621

# %%
#Set contrast factor to 2 
print("Creating model with contrast factor of 2")
contrast_model = create_model(contrast_factor = 2)
# Out:
# Creating model with contrast factor of 2
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 224, 224, 32)      2432
#
#  pool_1 (MaxPooling2D)       (None, 112, 112, 32)      0
#
#  conv_2 (Conv2D)             (None, 112, 112, 64)      51264
#
#  pool_2 (MaxPooling2D)       (None, 56, 56, 64)        0
#
#  flatten (Flatten)           (None, 200704)            0
#
#  fc_1 (Dense)                (None, 1024)              205521920
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 1)                 1025
#
# =================================================================
# Total params: 205,576,641
# Trainable params: 205,576,641
# Non-trainable params: 0
# _________________________________________________________________
# Reprocessing data
# Epoch 1/10
# 6/6 [==============================] - 2s 143ms/step - loss: 5.4077 - accuracy: 0.5316 - val_loss: 0.5207 - val_accuracy: 0.5161
# Epoch 2/10
# 6/6 [==============================] - 1s 137ms/step - loss: 0.5986 - accuracy: 0.6947 - val_loss: 0.3483 - val_accuracy: 0.7097
# Epoch 3/10
# 6/6 [==============================] - 1s 97ms/step - loss: 0.5032 - accuracy: 0.7579 - val_loss: 0.3201 - val_accuracy: 0.6774
# Epoch 4/10
# 6/6 [==============================] - 1s 95ms/step - loss: 0.3937 - accuracy: 0.8000 - val_loss: 0.3293 - val_accuracy: 0.7419
# Epoch 5/10
# 6/6 [==============================] - 1s 102ms/step - loss: 0.3743 - accuracy: 0.8053 - val_loss: 0.3419 - val_accuracy: 0.6774
# Epoch 6/10
# 6/6 [==============================] - 1s 96ms/step - loss: 0.3704 - accuracy: 0.7842 - val_loss: 0.3031 - val_accuracy: 0.6774
# Epoch 7/10
# 6/6 [==============================] - 1s 95ms/step - loss: 0.3381 - accuracy: 0.8000 - val_loss: 0.2335 - val_accuracy: 0.8710
# Epoch 8/10
# 6/6 [==============================] - 1s 99ms/step - loss: 0.3073 - accuracy: 0.8368 - val_loss: 0.2123 - val_accuracy: 0.9355
# Epoch 9/10
# 6/6 [==============================] - 1s 102ms/step - loss: 0.4620 - accuracy: 0.7895 - val_loss: 0.3036 - val_accuracy: 0.8065
# Epoch 10/10
# 6/6 [==============================] - 1s 118ms/step - loss: 0.4360 - accuracy: 0.8158 - val_loss: 0.2922 - val_accuracy: 0.6774
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2839 - accuracy: 0.9053
# Training accuracy:  0.9052631855010986
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2922 - accuracy: 0.6774
# Validation accuracy:  0.6774193644523621

# %%
#Set flip_on_train to false 
print("Creating model without flip on training data")
flip_model = create_model(flip_on_train = False)
# Out:
# Creating model without flip on training data
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_1 (Conv2D)             (None, 224, 224, 32)      2432
#
#  pool_1 (MaxPooling2D)       (None, 112, 112, 32)      0
#
#  conv_2 (Conv2D)             (None, 112, 112, 64)      51264
#
#  pool_2 (MaxPooling2D)       (None, 56, 56, 64)        0
#
#  flatten (Flatten)           (None, 200704)            0
#
#  fc_1 (Dense)                (None, 1024)              205521920
#
#  dropout (Dropout)           (None, 1024)              0
#
#  fc_2 (Dense)                (None, 1)                 1025
#
# =================================================================
# Total params: 205,576,641
# Trainable params: 205,576,641
# Non-trainable params: 0
# _________________________________________________________________
# Reprocessing data
# Epoch 1/10
# 6/6 [==============================] - 2s 140ms/step - loss: 6.7832 - accuracy: 0.5421 - val_loss: 0.4599 - val_accuracy: 0.7419
# Epoch 2/10
# 6/6 [==============================] - 1s 107ms/step - loss: 0.4656 - accuracy: 0.7737 - val_loss: 0.3246 - val_accuracy: 0.7742
# Epoch 3/10
# 6/6 [==============================] - 1s 107ms/step - loss: 0.4496 - accuracy: 0.7789 - val_loss: 0.2937 - val_accuracy: 0.7097
# Epoch 4/10
# 6/6 [==============================] - 1s 107ms/step - loss: 0.3641 - accuracy: 0.8316 - val_loss: 0.2891 - val_accuracy: 0.7097
# Epoch 5/10
# 6/6 [==============================] - 1s 110ms/step - loss: 0.3002 - accuracy: 0.8474 - val_loss: 0.2549 - val_accuracy: 0.8710
# Epoch 6/10
# 6/6 [==============================] - 1s 108ms/step - loss: 0.3222 - accuracy: 0.8211 - val_loss: 0.3332 - val_accuracy: 0.6774
# Epoch 7/10
# 6/6 [==============================] - 1s 100ms/step - loss: 0.3207 - accuracy: 0.8526 - val_loss: 0.3389 - val_accuracy: 0.6774
# Epoch 8/10
# 6/6 [==============================] - 1s 96ms/step - loss: 0.3403 - accuracy: 0.9000 - val_loss: 0.3206 - val_accuracy: 0.6774
# Epoch 9/10
# 6/6 [==============================] - 1s 95ms/step - loss: 0.2281 - accuracy: 0.8895 - val_loss: 0.3020 - val_accuracy: 0.6774
# Epoch 10/10
# 6/6 [==============================] - 1s 95ms/step - loss: 0.1831 - accuracy: 0.9000 - val_loss: 0.6180 - val_accuracy: 0.7097
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1116 - accuracy: 0.9579
# Training accuracy:  0.9578947424888611
# 1/1 [==============================] - 0s 49ms/step - loss: 0.6180 - accuracy: 0.7097
# Validation accuracy:  0.7096773982048035

# %%
#Calculate test data accuracy of model with
test_results = stride_model.evaluate(X_test, y_test)
print("The model with (2,2) strides achieves " + str(round(test_results[1], 2)) + " accuracy on the test data")
# Out:
# 2/2 [==============================] - 0s 24ms/step - loss: 0.3263 - accuracy: 0.8788
# The model with (2,2) strides achieves 0.88 accuracy on the test data
